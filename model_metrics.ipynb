# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
loss = pd.read_csv('models_history/history_last.csv')

# %%
loss.head()
# Out:
#        loss  dice_score  val_loss  val_dice_score     lr
# 0  0.064811    0.006550  0.024888        0.003175  0.001
# 1  0.022976    0.005321  0.022850        0.005926  0.001
# 2  0.019678    0.005998  0.016103        0.004875  0.001
# 3  0.014096    0.006153  0.014776        0.007360  0.001
# 4  0.011030    0.008257  0.010437        0.010137  0.001

# %%
loss[['dice_score', 'val_dice_score']].plot()
# Out:
# <Axes: >

# %%
loss[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
loss[['lr']].plot()
# Out:
# <Axes: >

# %% [markdown]
# As we can see, in almost 50 epochs we have been able to achieve stability on dice_score and loss.
